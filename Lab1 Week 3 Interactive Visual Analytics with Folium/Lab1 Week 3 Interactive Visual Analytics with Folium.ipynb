# %%
import piplite
await piplite.install(['folium'])
await piplite.install(['pandas'])

# %%
import folium
import pandas as pd

# %%
# Import folium MarkerCluster plugin
from folium.plugins import MarkerCluster
# Import folium MousePosition plugin
from folium.plugins import MousePosition
# Import folium DivIcon plugin
from folium.features import DivIcon

# %%
# Download and read the `spacex_launch_geo.csv`
from js import fetch
import io

URL = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_geo.csv'
resp = await fetch(URL)
spacex_csv_file = io.BytesIO((await resp.arrayBuffer()).to_py())
spacex_df=pd.read_csv(spacex_csv_file)

# %%
# Select relevant sub-columns: `Launch Site`, `Lat(Latitude)`, `Long(Longitude)`, `class`
spacex_df = spacex_df[['Launch Site', 'Lat', 'Long', 'class']]
launch_sites_df = spacex_df.groupby(['Launch Site'], as_index=False).first()
launch_sites_df = launch_sites_df[['Launch Site', 'Lat', 'Long']]
launch_sites_df
# Out:
#     Launch Site        Lat        Long
# 0   CCAFS LC-40  28.562302  -80.577356
# 1  CCAFS SLC-40  28.563197  -80.576820
# 2    KSC LC-39A  28.573255  -80.646895
# 3   VAFB SLC-4E  34.632834 -120.610745

# %%
# Start location is NASA Johnson Space Center
nasa_coordinate = [29.559684888503615, -95.0830971930759]
site_map = folium.Map(location=nasa_coordinate, zoom_start=10)

# %%
# Create a blue circle at NASA Johnson Space Center's coordinate with a popup label showing its name
circle = folium.Circle(nasa_coordinate, radius=1000, color='#d35400', fill=True).add_child(folium.Popup('NASA Johnson Space Center'))
# Create a blue circle at NASA Johnson Space Center's coordinate with a icon showing its name
marker = folium.map.Marker(
    nasa_coordinate,
    # Create an icon as a text label
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % 'NASA JSC',
        )
    )
site_map.add_child(circle)
site_map.add_child(marker)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# Initial the map
site_map = folium.Map(location=nasa_coordinate, zoom_start=5)
# For each launch site, add a Circle object based on its coordinate (Lat, Long) values. In addition, add Launch site name as a popup label
# Start Location is CCAFS LC-40
nasa_CCAFSLC = [28.562302, -80.577356]
site_map1 = folium.Map(location=nasa_CCAFSLC, zoom_start=10)


# Start Location is CCAFS SLC-40
nasa_CCAFSSLC = [28.563197, -80.576820]
site_map2 = folium.Map(location=nasa_CCAFSSLC, zoom_start=10)

# Start Location is KSC LC-39A
nasa_KSCLC = [28.573255, -80.646895]
site_map3 = folium.Map(location=nasa_KSCLC, zoom_start=10)

# Start Location is VAFB SLC-40
nasa_VAFBSLC = [34.632834, -120.610745]
site_map4 = folium.Map(location=nasa_VAFBSLC, zoom_start=10)

# %%
# Initial the map
site_map = folium.Map(location=nasa_coordinate, zoom_start=5)
# For each launch site, add a Circle object based on its coordinate (Lat, Long) values. In addition, add Launch site name as a popup label


# Start location is NASA Johnson Space Center
nasa_coordinate = [29.559684888503615, -95.0830971930759]
site_map = folium.Map(location=nasa_coordinate, zoom_start=10)
# Create a blue circle at NASA Johnson Space Center's coordinate with a popup label showing its name
circle = folium.Circle(nasa_coordinate, radius=1000, color='#d35400', fill=True).add_child(folium.Popup('NASA Johnson Space Center'))
# Create a blue circle at NASA Johnson Space Center's coordinate with a icon showing its name
marker = folium.map.Marker(
    nasa_coordinate,
    # Create an icon as a text label
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % 'NASA JSC',
        )
    )
site_map.add_child(circle)
site_map.add_child(marker)



# Start Location is CCAFS LC-40
nasa_CCAFSLC = [28.562302, -80.577356]
site_map1 = folium.Map(location=nasa_CCAFSLC, zoom_start=10)
# Create a blue circle at CCAFS LC-40 coordinate with a popup label showing its name
circle1 = folium.Circle(nasa_CCAFSLC, radius=1000, color='#d25400', fill=True).add_child(folium.Popup('NASA CCAFS LC-40'))
# Create a blue circle at CCAFS LC-40 coordinate with a icon showing its name
marker1 = folium.map.Marker(
    nasa_CCAFSLC,
    # Create an icon as a text label
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35430;"><b>%s</b></div>' % 'NASA CCAFS LC-40',
        )
    )
site_map.add_child(circle1)
site_map.add_child(marker1)



# Start Location is CCAFS SLC-40
nasa_CCAFSSLC = [28.563197, -80.576820]
site_map2 = folium.Map(location=nasa_CCAFSSLC, zoom_start=10)
# Create a blue circle at CCAFS SLC-40 coordinate with a popup label showing its name
circle2 = folium.Circle(nasa_CCAFSSLC, radius=1000, color='#h50000', fill=True).add_child(folium.Popup('NASA CCAFS SLC-40'))
# Create a blue circle at CCAFS LC-40 coordinate with a icon showing its name
marker2 = folium.map.Marker(
    nasa_CCAFSSLC,
    # Create an icon as a text label
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35430;"><b>%s</b></div>' % 'NASA CCAFS SLC-40',
        )
    )
site_map.add_child(circle2)
site_map.add_child(marker2)




# Start Location is KSC LC-39A
nasa_KSCLC = [28.573255, -80.646895]
site_map3 = folium.Map(location=nasa_KSCLC, zoom_start=10)
# Create a blue circle at KSC LC-39A coordinate with a popup label showing its name
circle3 = folium.Circle(nasa_KSCLC, radius=1000, color='#a44400', fill=True).add_child(folium.Popup('NASA KSC LC-39A'))
# Create a blue circle at KSC LC-39A coordinate with a icon showing its name
marker3 = folium.map.Marker(
    nasa_KSCLC,
    # Create an icon as a text label
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35430;"><b>%s</b></div>' % 'NASA KSC LC-39A',
        )
    )
site_map.add_child(circle3)
site_map.add_child(marker3)




# Start Location is VAFB SLC-40
nasa_VAFBSLC = [34.632834, -120.610745]
site_map4 = folium.Map(location=nasa_VAFBSLC, zoom_start=10)
# Create a blue circle at VAFB SLC-40 coordinate with a popup label showing its name
circle4 = folium.Circle(nasa_VAFBSLC, radius=1000, color='#a40000', fill=True).add_child(folium.Popup('NASA VAFB SLC-4E'))
# Create a blue circle at VAFB SLC-40 coordinate with a icon showing its name
marker4 = folium.map.Marker(
    nasa_VAFBSLC,
    # Create an icon as a text label
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35430;"><b>%s</b></div>' % 'NASA VAFB SLC-4E',
        )
    )
site_map.add_child(circle4)
site_map.add_child(marker4)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
spacex_df.tail(10)
# Out:
#      Launch Site        Lat       Long  class
# 46    KSC LC-39A  28.573255 -80.646895      1
# 47    KSC LC-39A  28.573255 -80.646895      1
# 48    KSC LC-39A  28.573255 -80.646895      1
# 49  CCAFS SLC-40  28.563197 -80.576820      1
# 50  CCAFS SLC-40  28.563197 -80.576820      1
# 51  CCAFS SLC-40  28.563197 -80.576820      0
# 52  CCAFS SLC-40  28.563197 -80.576820      0
# 53  CCAFS SLC-40  28.563197 -80.576820      0
# 54  CCAFS SLC-40  28.563197 -80.576820      1
# 55  CCAFS SLC-40  28.563197 -80.576820      0

# %%
marker_cluster = MarkerCluster()

# %%
# Function to assign color to launch outcome
def assign_marker_color(launch_outcome):
    if launch_outcome == 1:
        return 'green'
    else:
        return 'red'
    
spacex_df['marker_color'] = spacex_df['class'].apply(assign_marker_color)
spacex_df.tail(10)
# Out:
#      Launch Site        Lat       Long  class marker_color
# 46    KSC LC-39A  28.573255 -80.646895      1        green
# 47    KSC LC-39A  28.573255 -80.646895      1        green
# 48    KSC LC-39A  28.573255 -80.646895      1        green
# 49  CCAFS SLC-40  28.563197 -80.576820      1        green
# 50  CCAFS SLC-40  28.563197 -80.576820      1        green
# 51  CCAFS SLC-40  28.563197 -80.576820      0          red
# 52  CCAFS SLC-40  28.563197 -80.576820      0          red
# 53  CCAFS SLC-40  28.563197 -80.576820      0          red
# 54  CCAFS SLC-40  28.563197 -80.576820      1        green
# 55  CCAFS SLC-40  28.563197 -80.576820      0          red

# %%
# Add marker_cluster to current site_map
site_map.add_child(marker_cluster)

# for each row in spacex_df data frame
# create a Marker object with its coordinate
# and customize the Marker's icon property to indicate if this launch was successed or failed, 
# e.g., icon=folium.Icon(color='white', icon_color=row['marker_color']
for index, record in spacex_df.iterrows():
    # TODO: Create and add a Marker cluster to the site map
    marker = folium.Marker([record[1], record[2]], icon=folium.Icon(color='white', icon_color=record[4]))
    marker_cluster.add_child(marker)

site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# Add Mouse Position to get the coordinate (Lat, Long) for a mouse over on the map
formatter = "function(num) {return L.Util.formatNum(num, 5);};"
mouse_position = MousePosition(
    position='topright',
    separator=' Long: ',
    empty_string='NaN',
    lng_first=False,
    num_digits=20,
    prefix='Lat:',
    lat_formatter=formatter,
    lng_formatter=formatter,
)

site_map.add_child(mouse_position)
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
from math import sin, cos, sqrt, atan2, radians

def calculate_distance(lat1, lon1, lat2, lon2):
    # approximate radius of earth in km
    R = 6373.0

    lat1 = radians(lat1)
    lon1 = radians(lon1)
    lat2 = radians(lat2)
    lon2 = radians(lon2)

    dlon = lon2 - lon1
    dlat = lat2 - lat1

    a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))

    distance = R * c
    return distance

# %%
# find coordinate of the closet coastline
# e.g.,: Lat: 28.56367  Lon: -80.57163
# distance_coastline = calculate_distance(launch_site_lat, launch_site_lon, coastline_lat, coastline_lon)
# distance_coastline NASA CCAFS LC-40
distance_coastline_CCAFSLC = calculate_distance(28.562302, -80.577356, 28.56417, -80.56721)
print("The coastline distance from NASA CCAFS LC-40 is:",distance_coastline_CCAFSLC)


# distance_coastline NASA CCAFS SLC-40
distance_coastline_CCAFSSLC = calculate_distance(28.563197, -80.576820, 28.56417, -80.56721)
print("The coastline distance from NASA CCAFS SLC-40 is:",distance_coastline_CCAFSSLC)


# distance_coastline NASA KSC LC-39A
distance_coastline_KSCLC = calculate_distance(28.573255, -80.646895, 28.57616, -80.57081)
print("The coastline distance from NASA KSC LC-39A is:",distance_coastline_KSCLC)


# ditance_coastline NASA VAFB SLC-4E
distance_coastline_VAFBSLC = calculate_distance(34.632834, -120.610745, 34.63653, -120.62611)
print("The coastline distance from NASA VAFB SLC-4E is:",distance_coastline_VAFBSLC)
# Out:
# The coastline distance from NASA CCAFS LC-40 is: 1.012727068743276
# The coastline distance from NASA CCAFS SLC-40 is: 0.9450341413777582
# The coastline distance from NASA KSC LC-39A is: 7.439109624007321
# The coastline distance from NASA VAFB SLC-4E is: 1.4650527387471013

# %%
# Create and add a folium.Marker on your selected closest coastline point on the map
# Display the distance between coastline point and launch site using the icon property 
# for example
# distance_marker = folium.Marker(
#    coordinate,
#    icon=DivIcon(
#        icon_size=(20,20),
#        icon_anchor=(0,0),
#        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance),
#        )
#    )
# Create and add a folium.Marker on your selected closest coastline point on the map
# Display the distance between coastline point and launch site using the icon property 
# for example

# distance CCAFS LC-40
distance_marker1 = folium.Marker(
    nasa_CCAFSLC, 
    icon=DivIcon(
        icon_size=(20,20), 
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_coastline_CCAFSLC)
    )
)


# distance CCAFS SLC-40
distance_marker2 = folium.Marker(
    nasa_CCAFSSLC, 
    icon=DivIcon(
        icon_size=(20,20), 
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_coastline_CCAFSSLC)
    )
)


# distance KSC LC-39A
distance_marker3 = folium.Marker(
    nasa_KSCLC, 
    icon=DivIcon(
        icon_size=(20,20), 
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_coastline_KSCLC)
    )
)


# distance VAFB SLC-4E
distance_marker4 = folium.Marker(
    nasa_VAFBSLC, 
    icon=DivIcon(
        icon_size=(20,20), 
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_coastline_VAFBSLC)
    )
)


site_map.add_child(distance_marker1)
site_map.add_child(distance_marker2)
site_map.add_child(distance_marker3)
site_map.add_child(distance_marker4)
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# Create a `folium.PolyLine` object using the coastline coordinates and launch site coordinate

# distance CCAFS LC-40
lines1=folium.PolyLine(locations=[[28.56417, -80.56721], [28.562302, -80.577356]], weight=1)
#Create a text of the distance in kilometers
distance_CCAFSLC = [28.56417,-80.56721]
distance1 = folium.map.Marker(
    distance_CCAFSLC,
    #Create on icon a text label
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_coastline_CCAFSLC),
        )
    )

# distance_coastline NASA CCAFS SLC-40
lines2=folium.PolyLine(locations=[[28.56417, -80.56721], [28.563197, -80.576820]], weight=1)
#Create a text of the distance in kilometers
distance_CCAFSSLC = [28.56449,-80.56729]
distance2 = folium.map.Marker(
    distance_CCAFSSLC,
    #Create on icon a text label
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_coastline_CCAFSSLC),
        )
    )

# distance_coastline NASA KSC LC-39A
lines3=folium.PolyLine(locations=[[28.57616, -80.57081], [28.573255, -80.646895]], weight=1)
#Create a text of the distance in kilometers
distance_KSCLC = [28.57616,-80.57081]
distance3 = folium.map.Marker(
    distance_KSCLC,
    #Create on icon a text label
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_coastline_KSCLC),
        )
    )

# distance_coastline NASA VAFB SLC-4E
lines4=folium.PolyLine(locations=[[34.63653, -120.62611], [34.632834, -120.610745]], weight=1)
#Create a text of the distance in kilometers
distance_VAFBSLC = [34.63653,-120.62611]
distance4 = folium.map.Marker(
    distance_VAFBSLC,
    #Create on icon a text label
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_coastline_VAFBSLC),
        )
    )




# lines=folium.PolyLine(locations=coordinates, weight=1)
site_map.add_child(lines1)
site_map.add_child(distance1)
site_map.add_child(lines2)
site_map.add_child(distance2)
site_map.add_child(lines3)
site_map.add_child(distance3)
site_map.add_child(lines4)
site_map.add_child(distance4)

site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# Draw lines between launch sites and closest cities
# cities (Cape Canaveral) close to CCAFS LC-40[Lat, Long], Lat:28.4019   Long:-80.60464

# cities (Cape Canaveral) close to CCAFS SLC-40[Lat, Long], Lat:28.4019   Long:-80.60464

# cities (Titusville) close to KSC LC-39A[Lat, Long], Lat:28.61221   Long:-80.808

# cities (Lompoc) close to VAFB SLC-4E[Lat, Long], Lat:34.63911   Long:-120.45788



# Cities distance to CCAFS LC-40
lines_cities1=folium.PolyLine(locations=[[28.4019, -80.60464], [28.562302, -80.577356]], weight=1)
#Calculate distance Cape Canaveral to CCAFS LC-40
distance_cities_CCAFSLC=calculate_distance(28.562302,-80.577356,28.4019,-80.60464)
print("The cities distance from CCAFS LC-40 is:",distance_cities_CCAFSLC)

#Create a text of the distance in kilometers
distance_CCAFSLC_CapeCanaveral = [28.4019,-80.60464]
distance_1 = folium.map.Marker(
    distance_CCAFSLC_CapeCanaveral,
    #Create on icon a text label
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_cities_CCAFSLC),
        )
    )




# Cities distance to CCAFS SLC-40
lines_cities2=folium.PolyLine(locations=[[28.4019, -80.60464], [28.563197, -80.576820]], weight=1)
#Calculate distance Cape Canaveral to CCAFS SLC-40
distance_cities_CCAFSSLC=calculate_distance(28.563197, -80.576820,28.4019, -80.60464)
print("The cities distance from CCAFS SLC-40 is:",distance_cities_CCAFSSLC)

#Create a text of the distance in kilometers
distance_CCAFSSLC_CapeCanaveral = [28.4019, -80.60464]
distance_2 = folium.map.Marker(
    distance_CCAFSSLC_CapeCanaveral,
    #Create on icon a text label
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_cities_CCAFSSLC),
        )
    )






# Cities distance to KSC LC-39A
lines_cities3=folium.PolyLine(locations=[[28.61221,-80.808], [28.573255, -80.646895]], weight=1)
#Calculate distance Cape Canaveral to CCAFS SLC-40
distance_cities_KSCLC=calculate_distance(28.573255, -80.646895, 28.61221,-80.808)
print("The cities distance from KSC LC-39A is:",distance_cities_KSCLC)

#Create a text of the distance in kilometers
distance_KSCLC_Titusville = [28.61221,-80.808]
distance_3 = folium.map.Marker(
    distance_KSCLC_Titusville,
    #Create on icon a text label
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_cities_KSCLC),
        )
    )




# Cities distance to VAFB SLC-4E
lines_cities4=folium.PolyLine(locations=[[34.63911,-120.45788],[34.632834, -120.610745]], weight=1)
#Calculate distance Cape Canaveral to CCAFS SLC-40
distance_cities_VAFBSLC=calculate_distance(34.632834, -120.610745,34.63911,-120.45788)
print("The cities distance from VAFB SLC-4E is:",distance_cities_VAFBSLC)

#Create a text of the distance in kilometers
distance_VAFBSLC_Lompoc = [34.63911,-120.45792]
distance_4 = folium.map.Marker(
    distance_VAFBSLC_Lompoc,
    #Create on icon a text label
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_cities_VAFBSLC),
        )
    )




# lines=folium.PolyLine(locations=coordinates, weight=1)
site_map.add_child(lines_cities1)
site_map.add_child(distance_1)
site_map.add_child(lines_cities2)
site_map.add_child(distance_2)
site_map.add_child(lines_cities3)
site_map.add_child(distance_3)
site_map.add_child(lines_cities4)
site_map.add_child(distance_4)

site_map
# Out:
# The cities distance from CCAFS LC-40 is: 18.03979307483421
# The cities distance from CCAFS SLC-40 is: 18.14603433577032
# The cities distance from KSC LC-39A is: 16.319973382204203
# The cities distance from VAFB SLC-4E is: 14.007249839384956
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
# ...

# %%
# Draw lines between launch sites and railway
# railway close to CCAFS LC-40[Lat, Long], Lat:28.57209   Long:-80.58526

# railway close to CCAFS SLC-40[Lat, Long], Lat:28.57209   Long:-80.58526

# railway close to KSC LC-39A[Lat, Long], Lat:28.57378   Long:-80.65428

# railway close to VAFB SLC-4E[Lat, Long], Lat:34.63363   Long:-120.62475

# Cities distance to CCAFS LC-40
lines_railway1=folium.PolyLine(locations=[[28.57209, -80.58526], [28.562302, -80.577356]], weight=1)
#Calculate distance Cape Canaveral to CCAFS LC-40
distance_railway_CCAFSLC=calculate_distance(28.562302,-80.577356,28.57209, -80.58526)
print("The railway distance from CCAFS LC-40 is:",distance_railway_CCAFSLC)

#Create a text of the distance in kilometers
distance_CCAFSLC_railway = [28.57209, -80.58526]
distance_r1 = folium.map.Marker(
    distance_CCAFSLC_railway,
    #Create on icon a text label
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_railway_CCAFSLC),
        )
    )




# Cities distance to CCAFS SLC-40
lines_railway2=folium.PolyLine(locations=[[28.57209, -80.58526], [28.563197, -80.576820]], weight=1)
#Calculate distance Cape Canaveral to CCAFS SLC-40
distance_railway_CCAFSSLC=calculate_distance(28.563197, -80.576820,28.57209, -80.58526)
print("The railway distance from CCAFS SLC-40 is:",distance_railway_CCAFSSLC)

#Create a text of the distance in kilometers
distance_CCAFSSLC_railway = [28.57209, -80.58526]
distance_r2 = folium.map.Marker(
    distance_CCAFSSLC_railway,
    #Create on icon a text label
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_railway_CCAFSSLC),
        )
    )






# Cities distance to KSC LC-39A
lines_railway3=folium.PolyLine(locations=[[28.57378,-80.65428], [28.573255, -80.646895]], weight=1)
#Calculate distance Cape Canaveral to CCAFS SLC-40
distance_railway_KSCLC=calculate_distance(28.573255, -80.646895, 28.57378,-80.65428)
print("The railway distance from KSC LC-39A is:",distance_railway_KSCLC)

#Create a text of the distance in kilometers
distance_KSCLC_railway = [28.57378,-80.65428]
distance_r3 = folium.map.Marker(
    distance_KSCLC_railway,
    #Create on icon a text label
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_railway_KSCLC),
        )
    )




# Cities distance to VAFB SLC-4E
lines_railway4=folium.PolyLine(locations=[[34.63363,-120.62475],[34.632834, -120.610745]], weight=1)
#Calculate distance Cape Canaveral to CCAFS SLC-40
distance_railway_VAFBSLC=calculate_distance(34.632834, -120.610745,34.63363,-120.62475)
print("The railway distance from VAFB SLC-4E is:",distance_railway_VAFBSLC)

#Create a text of the distance in kilometers
distance_VAFBSLC_railway = [34.63363,-120.62475]
distance_r4 = folium.map.Marker(
    distance_VAFBSLC_railway,
    #Create on icon a text label
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_railway_VAFBSLC),
        )
    )




# lines=folium.PolyLine(locations=coordinates, weight=1)
site_map.add_child(lines_railway1)
site_map.add_child(distance_r1)
site_map.add_child(lines_railway2)
site_map.add_child(distance_r2)
site_map.add_child(lines_railway3)
site_map.add_child(distance_r3)
site_map.add_child(lines_railway4)
site_map.add_child(distance_r4)

site_map
# Out:
# The railway distance from CCAFS LC-40 is: 1.3347243202369456
# The railway distance from CCAFS SLC-40 is: 1.2877223561728453
# The railway distance from KSC LC-39A is: 0.7237449454888991
# The railway distance from VAFB SLC-4E is: 1.2848013583063345
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
# ...

# %%
# Draw lines between launch sites and highway
# highway close to CCAFS LC-40[Lat, Long], Lat:28.56306   Long:-80.57077

# highway close to CCAFS SLC-40[Lat, Long], Lat: 28.56306   Long:-80.57077

# highway close to KSC LC-39A[Lat, Long], Lat:28.57342   Long:-80.65553

# highway close to VAFB SLC-4E[Lat, Long], Lat:34.50182   Long:-120.49616


# Highway distance to CCAFS LC-40
lines_highway1=folium.PolyLine(locations=[[28.56306,-80.57077], [28.562302, -80.577356]], weight=1)
#Calculate distance Cape Canaveral to CCAFS LC-40
distance_highway_CCAFSLC=calculate_distance(28.562302,-80.577356,28.56306,-80.57077)
print("The highway distance from CCAFS LC-40 is:",distance_highway_CCAFSLC)

#Create a text of the distance in kilometers
distance_CCAFSLC_highway = [28.56306,-80.57077]
distance_h1 = folium.map.Marker(
    distance_CCAFSLC_railway,
    #Create on icon a text label
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_highway_CCAFSLC),
        )
    )




# Cities distance to CCAFS SLC-40
lines_highway2=folium.PolyLine(locations=[[28.56306, -80.57077], [28.563197, -80.576820]], weight=1)
#Calculate distance Cape Canaveral to CCAFS SLC-40
distance_highway_CCAFSSLC=calculate_distance(28.563197, -80.576820,28.56306, -80.57077)
print("The highway distance from CCAFS SLC-40 is:",distance_highway_CCAFSSLC)

#Create a text of the distance in kilometers
distance_CCAFSSLC_highway = [28.56306, -80.57077]
distance_h2 = folium.map.Marker(
    distance_CCAFSSLC_highway,
    #Create on icon a text label
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_highway_CCAFSSLC),
        )
    )






# Cities distance to KSC LC-39A
lines_highway3=folium.PolyLine(locations=[[28.57342,-80.65553], [28.573255, -80.646895]], weight=1)
#Calculate distance Cape Canaveral to CCAFS SLC-40
distance_highway_KSCLC=calculate_distance(28.573255, -80.646895, 28.57342, -80.65553)
print("The highway distance from KSC LC-39A is:",distance_highway_KSCLC)

#Create a text of the distance in kilometers
distance_KSCLC_highway = [28.57342, -80.65553]
distance_h3 = folium.map.Marker(
    distance_KSCLC_highway,
    #Create on icon a text label
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_highway_KSCLC),
        )
    )




# Highway distance to VAFB SLC-4E
lines_highway4=folium.PolyLine(locations=[[34.50182,-120.49616],[34.632834, -120.610745]], weight=1)
#Calculate distance Cape Canaveral to CCAFS SLC-40
distance_highway_VAFBSLC=calculate_distance(34.632834, -120.610745,34.50182,-120.49616)
print("The highway distance from VAFB SLC-4E is:",distance_highway_VAFBSLC)

#Create a text of the distance in kilometers
distance_VAFBSLC_highway = [34.50182,-120.49616]
distance_h4 = folium.map.Marker(
    distance_VAFBSLC_highway,
    #Create on icon a text label
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_highway_VAFBSLC),
        )
    )




# lines=folium.PolyLine(locations=coordinates, weight=1)
site_map.add_child(lines_highway1)
site_map.add_child(distance_h1)
site_map.add_child(lines_highway2)
site_map.add_child(distance_h2)
site_map.add_child(lines_highway3)
site_map.add_child(distance_h3)
site_map.add_child(lines_highway4)
site_map.add_child(distance_h4)

site_map
# Out:
# The highway distance from CCAFS LC-40 is: 0.6489038637432287
# The highway distance from CCAFS SLC-40 is: 0.5912338842728617
# The highway distance from KSC LC-39A is: 0.8436894679755286
# The highway distance from VAFB SLC-4E is: 17.958622217951373
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
# ...
